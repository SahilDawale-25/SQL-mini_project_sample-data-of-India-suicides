# %%
import pandas as pd

df = pd.read_csv("sucide_data.csv")

# Number of rows per state (adjust as needed)
rows_per_state = 30

sampled_df = df.groupby("State").head(rows_per_state)

# Save the balanced subset
sampled_df.to_csv("suicides_sample_1000.csv", index=False)

print("Done. Total rows:", len(sampled_df))
# Out:
# Done. Total rows: 1140

# %%
sampled_df
# Out:
#                 State  Year Type_code  \
# 0       A & N Islands  2001    Causes
# 1       A & N Islands  2001    Causes
# 2       A & N Islands  2001    Causes
# 3       A & N Islands  2001    Causes
# 4       A & N Islands  2001    Causes
# ...               ...   ...       ...
# 230764    West Bengal  2001    Causes
# 230765    West Bengal  2001    Causes
# 230766    West Bengal  2001    Causes
# 230767    West Bengal  2001    Causes
# 230768    West Bengal  2001    Causes
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...
